# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv("/content/college_1.csv")

print(df1.shape)
df1.head()
# Out:
# (84, 7)
#           Name  python  ...                        Department  Rising
# 0    A.Dharani    82.0  ...  Computer Science and Engineering       0
# 1  V.JEEVITHA     82.0  ...  Computer Science and Engineering       0
# 2  HEMAVATHI.R   100.0  ...  Computer Science and Engineering       0
# 3  Mugunthan S   100.0  ...  Computer Science and Engineering       0
# 4  Sathammai.S   100.0  ...  Computer Science and Engineering       0
#
# [5 rows x 7 columns]

# %%
df2 = pd.read_csv("/content/college_2.csv")

print(df2.shape)
df2.head()
# Out:
# (35, 9)
#                 Name  python  ...                                 Department  Rising
# 0      ASHOK KUMAR K     100  ...     Electronics and Electrical Engineering       0
# 1            Chandru       0  ...           Computer Science and Engineering     340
# 2  Ganesh Ramkumar R      -1  ...           Computer Science and Engineering    2000
# 3    Bodipudi Harini      -1  ...  Electronics and Communication Engineering       0
# 4          VIINU V P      -1  ...     Electronics and Electrical Engineering       0
#
# [5 rows x 9 columns]

# %%
df = pd.concat([df1,df2])

print(df.shape)
df
# Out:
# (119, 9)
#              Name  python  mysql  ...  Rising  python_en computational_thinking
# 0       A.Dharani    82.0   20.0  ...       0        NaN                    NaN
# 1     V.JEEVITHA     82.0   20.0  ...       0        NaN                    NaN
# 2     HEMAVATHI.R   100.0  100.0  ...       0        NaN                    NaN
# 3     Mugunthan S   100.0   47.0  ...       0        NaN                    NaN
# 4     Sathammai.S   100.0    8.0  ...       0        NaN                    NaN
# ..            ...     ...    ...  ...     ...        ...                    ...
# 30  praveen raj j    24.0    0.0  ...       0       -1.0                    0.0
# 31     AMARNATH D    -1.0   12.0  ...       0       52.0                   -1.0
# 32           bala    32.0    0.0  ...       0       49.0                   -1.0
# 33           XY Z    -1.0   -1.0  ...       0       20.0                   -1.0
# 34      Hariharan    -1.0   -1.0  ...       0       -1.0                    0.0
#
# [119 rows x 9 columns]

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
# consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

exceed = df[df['CodeKata Score']>15000]
exceed.reset_index(drop=True)
# Out:
#             Name  python  mysql  ...  Rising  python_en computational_thinking
# 0      A.Dharani    82.0   20.0  ...       0        NaN                    NaN
# 1    V.JEEVITHA     82.0   20.0  ...       0        NaN                    NaN
# 2    HEMAVATHI.R   100.0  100.0  ...       0        NaN                    NaN
# 3  ASHOK KUMAR K   100.0   31.0  ...       0        0.0                    9.0
#
# [4 rows x 9 columns]

# %%
exceed.to_csv("Exceeded expectations.csv",index=False)

# %%
# if 10000<codekata score<15000 (Reached_expectations.csv)

reached = df[(df['CodeKata Score']>10000) & (df['CodeKata Score']<15000)]
reached.reset_index(drop=True)
# Out:
#                 Name  python  mysql  ...  Rising  python_en computational_thinking
# 0        Mugunthan S   100.0   47.0  ...       0        NaN                    NaN
# 1            Chandru     0.0    0.0  ...     340       20.0                    0.0
# 2  Ganesh Ramkumar R    -1.0   24.0  ...    2000       55.0                    6.0
# 3    Bodipudi Harini    -1.0   35.0  ...       0        0.0                   -1.0
#
# [4 rows x 9 columns]

# %%
reached.to_csv("Reached_expectations.csv",index=False)

# %%
# if 7000<codekata score<10000 (Needs_Improvement.csv)

improve = df[(df['CodeKata Score']>7000) & (df['CodeKata Score']<10000)]
improve.reset_index(drop=True)
# Out:
#                       Name  python  ...  python_en  computational_thinking
# 0              Sathammai.S   100.0  ...        NaN                     NaN
# 1             NIVEESHWAR S   100.0  ...        NaN                     NaN
# 2            KALAIARASAN K    85.0  ...        NaN                     NaN
# 3     MOHAMED ZUBAIR AHMED    82.0  ...        NaN                     NaN
# 4                VIINU V P    -1.0  ...      100.0                    -1.0
# 5               Poojitha Y     0.0  ...       78.0                     0.0
# 6   Gowtham Chandrasekaran    -1.0  ...        0.0                     3.0
# 7                Gowtham R    -1.0  ...       60.0                     6.0
# 8                 shifak N    58.0  ...        0.0                     0.0
# 9                  Balaji     -1.0  ...      100.0                     0.0
# 10                Rushitha    -1.0  ...       15.0                     9.0
# 11    Balaraman Muthupandi    -1.0  ...        9.0                     0.0
# 12                JPradhap   100.0  ...        0.0                     0.0
# 13           SRIRAMKUMAR B    -1.0  ...        0.0                     0.0
# 14               Praneetha    -1.0  ...       23.0                    -1.0
# 15             Rahul Raj K    -1.0  ...        0.0                     0.0
# 16                 Guhan S    -1.0  ...       72.0                    39.0
# 17            Suryarajan S    -1.0  ...       63.0                     0.0
#
# [18 rows x 9 columns]

# %%
improve.to_csv("Needs_Improvement.csv",index=False)

# %%
# if codekate score < 7000 (Unsatisfactory.csv)

unsatisfied = df[df['CodeKata Score']<7000]
unsatisfied.reset_index(drop=True)
# Out:
#                Name  python  mysql  ...  Rising  python_en computational_thinking
# 0        J.SUGANTHI    27.0  50.00  ...       0        NaN                    NaN
# 1      thamizhpaana    29.0   0.00  ...       0        NaN                    NaN
# 2   Iyappan Samiraj    50.0  24.00  ...       0        NaN                    NaN
# 3      Ponniyamma.R   100.0  11.25  ...       0        NaN                    NaN
# 4         SABAPATHI   100.0   0.00  ...       0        NaN                    NaN
# ..              ...     ...    ...  ...     ...        ...                    ...
# 88    praveen raj j    24.0   0.00  ...       0       -1.0                    0.0
# 89       AMARNATH D    -1.0  12.00  ...       0       52.0                   -1.0
# 90             bala    32.0   0.00  ...       0       49.0                   -1.0
# 91             XY Z    -1.0  -1.00  ...       0       20.0                   -1.0
# 92        Hariharan    -1.0  -1.00  ...       0       -1.0                    0.0
#
# [93 rows x 9 columns]

# %%
unsatisfied.to_csv("Unsatisfactory.csv",index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df['Previous Geekions'].mean(), df['CodeKata Score'].mean()
# Out:
# (3842.3529411764707, 4051.764705882353)

# %% [markdown]
# ###### No of students participated

# %%
len(df['Name'].unique())
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
print(df['python'].mean())
print(df['mysql'].mean())
print(df['python_en'].mean())
print(df['computational_thinking'].mean())
# Out:
# 54.35294117647059
# 23.5
# 29.65714285714286
# 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values('CodeKata Score',ascending=False)[:3]
# Out:
#           Name  python  mysql  ...  Rising  python_en computational_thinking
# 0    A.Dharani    82.0   20.0  ...       0        NaN                    NaN
# 1  V.JEEVITHA     82.0   20.0  ...       0        NaN                    NaN
# 2  HEMAVATHI.R   100.0  100.0  ...       0        NaN                    NaN
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values('Previous Geekions',ascending=False)[:3]
# Out:
#           Name  python  mysql  ...  Rising  python_en computational_thinking
# 0    A.Dharani    82.0   20.0  ...       0        NaN                    NaN
# 1  V.JEEVITHA     82.0   20.0  ...       0        NaN                    NaN
# 2  HEMAVATHI.R   100.0  100.0  ...       0        NaN                    NaN
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
fig = px.pie(df,values='CodeKata Score',names='Department')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="159dbd5a-cf5c-49ad-ba39-6590d26cefe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("159dbd5a-cf5c-49ad-ba39-6590d26cefe0")) {                    Plotly.newPlot(                        "159dbd5a-cf5c-49ad-ba39-6590d26cefe0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Department=%{label}<br>CodeKata Score=%{value}<extra></extra>","labels":["Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engi ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df1 = df.sort_values('CodeKata Score',ascending=True)
fig = px.bar(df1,'Department','CodeKata Score',color='Previous Geekions',hover_name='Name')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9c0f17ff-e851-4796-8a60-fc91616c4294" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c0f17ff-e851-4796-8a60-fc91616c4294")) {                    Plotly.newPlot(                        "9c0f17ff-e851-4796-8a60-fc91616c4294",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Department=%{x}<br>CodeKata Score=%{y}<br>Previous Geekions=%{marker.color}<extra></extra>","hovertext":["Hariharan","KarthikeyanS","BARATH.P","XY Z","mohamed nabi","yaser ahamed.A","N.Ajith kumar","vikneshwaran","J.JAYANTHI","Arun","santhosh","J.Bhuvaneshwari","rajesh kumar.r","karthika.G","vignesh B","m.keerthana","Subhashini","sivaranjini","gousalya","Evanasundari.K","jayapratha","k.parvathi","E.Nalini","Haasini","Aravind","muvendiran.m","Thivviya","M.Nisha@mary","M.PRIYA","pravina","kaviyarasi.k","u.abarna","RANJITH.R","GUNAMATHI.S","Nivetha.S","Deivani.S","bavithra","b.akshaya","MadhumathiB","siva sai perumal polisetti","PRAVEENA K","ponni.p","v.gowsalya","vijayakumar","ABIRAMI.S","HSharukhan","bala","vignesh","Stephen","nivedha.s","AMARNATH D","selvakumar","Barath D","tamilarasi","SOWMIYA.V","SarumathiR","Kaliaperumal G","manikandan","praveen raj j","chithra","pooja priya.B","shankari","sri dharshini","Tpavithra","MEERA.M","Abishak s","balaji","Yuvasri","kamalishwari","s.janani","M.Karthikeyan","S.srinivasan","Vimalesh Fernando","Abirami Anbazhagan","v.vithyasri","sridhar.s","PRIYANKA .S","Pavithra","Melvin Dukles.R","SHAIK DANISH","P.GOVARDHANAN","RAGHAVAN","MUKESH S M","SABAPATHI","Ponniyamma.R","Iyappan Samiraj","thamizhpaana","santhoshini","J.SUGANTHI","pradeeban","PremsagarReddy","Leelakrishna","Narasimhan Y L","MOHAMED ZUBAIR AHMED","Suryarajan S","Guhan S","Rahul Raj K","Praneetha","KALAIARASAN K","SRIRAMKUMAR B","JPradhap","Balaraman Muthupandi","Rushitha","Balaji ","NIVEESHWAR S","shifak N","Gowtham R","Gowtham Chandrasekaran"," Poojitha Y","Sathammai.S","VIINU V P","Bodipudi Harini","Mugunthan S","Ganesh Ramkumar R","Chandru","ASHOK KUMAR K","HEMAVATHI.R","V.JEEVITHA ","A.Dharani"],"legendgroup":"","marker":{"color":[0,0,0,0,0,0,0,40,40,40,60,100,100,120,120,120,120,160,170,180,200,260,270,300,380,410,490,580,690,720,760,770,800,850,950,980,1020,1100,1130,1240,1320,1350,1440,1580,1580,1680,1720,1740,1880,1880,1890,1900,1910,1910,2160,2240,2260,2360,2380,2410,2570,3000,3110,3200,3200,3220,3280,3460,3665,3915,4020,4090,4170,4320,4370,3860,4510,4600,4800,4050,5050,5120,5200,5280,5380,5400,5500,3910,5860,6060,5290,5300,4800,7020,6710,7310,6280,7170,7750,6400,7340,7670,7470,6170,8200,5180,8650,7250,7210,8980,9150,10040,10610,8790,14150,19400,19680,21740,24500],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Computer Science and Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Computer Science and Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering","Electronics and Electrical Engineering","Electronics and Communication Engineering","Electronics and Communication Engineering","Computer Science and Engineering","Computer Science and Engineering","Electronics and Electrical Engineering","Electronics and Communication Engineering","Computer S ...
